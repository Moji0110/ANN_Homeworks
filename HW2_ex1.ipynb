# %% [markdown]
# # HW1_ex_1_1

# %% [markdown]
# # part A

# %%
import numpy as np
import matplotlib.pyplot as plt


def f_1(x1, x2):

    return 4*np.power(x1,2) - np.multiply(x1,x2) + 7 - x1 - x2

def dx1(x1, x2):

    return 8*x1 - x2 - 1

def dx2(x1, x2):

    return -1*x1 - 1

x1 = np.arange(-0.5, 1, 0.001)
x2 = np.arange(-0.5, 1, 0.001)

X1, X2 = np.meshgrid(x1, x2)
Z = f_1(X1, X2)

lr = 0.01

x1_init = 0
x2_init = 0

X1_trajectory = []
X2_trajectory = []

grad_mag_x1 = []
grad_mag_x2 = []

X1_trajectory.append(x1_init)
X2_trajectory.append(x2_init)

for i in range(4):
    
    grad_x1 = lr*dx1(x1_init, x2_init)
    grad_x2 = lr*dx2(x1_init, x2_init)
    x1_new = x1_init -grad_x1
    x2_new = x2_init -grad_x2

    x1_init = x1_new
    x2_init = x2_new

    grad_mag_x1.append(grad_x1)
    grad_mag_x2.append(grad_x2)

    if i == 3:
        grad_x1 = lr*dx1(x1_init, x2_init)
        grad_x2 = lr*dx2(x1_init, x2_init)
        grad_mag_x1.append(grad_x1)
        grad_mag_x2.append(grad_x2)
    
    X1_trajectory.append(x1_init)
    X2_trajectory.append(x2_init)



fig = plt.figure(figsize = (16,8))
ax = fig.add_subplot(1, 2, 1)
ax.contour(X1, X2, Z)
ax.quiver(X1_trajectory, X2_trajectory, grad_mag_x1, grad_mag_x2, scale_units = 'xy', angles = 'xy', scale = 1, color = 'r', alpha = .9)
ax = fig.add_subplot(1, 2, 2, projection='3d')
ax.plot_surface(X1, X2, Z,rstride = 5, cstride = 5, cmap = 'jet', alpha=0.5)
ax.plot3D(X1_trajectory, X2_trajectory, f_1(X1_trajectory, X2_trajectory), marker = '*', color = 'r', alpha = .4, label = 'Gradient descent')
plt.show()

# %% [markdown]
# # Part B

# %%
def f_2(x1, x2):

    return np.power(x1,7) + np.multiply(x1,x2) - np.multiply(np.power(x1, 3), np.power(x2, 2))

def dx1(x1, x2):

    return 7*np.power(x1,6) + x2 - 3*np.multiply(np.power(x1, 2), np.power(x2, 2))

def dx2(x1, x2):

    return x1 - 2*np.multiply(np.power(x1, 3), x2)

x1 = np.arange(-10, 10, 0.01)
x2 = np.arange(-10, 10, 0.01)

X1, X2 = np.meshgrid(x1, x2)
Z = f_2(X1, X2)

lr = 0.005

x1_init = 2
x2_init = 1

X1_trajectory = []
X2_trajectory = []

grad_mag_x1 = []
grad_mag_x2 = []

X1_trajectory.append(x1_init)
X2_trajectory.append(x2_init)

for i in range(4):
    
    grad_x1 = lr*dx1(x1_init, x2_init)
    grad_x2 = lr*dx2(x1_init, x2_init)
    x1_new = x1_init -grad_x1
    x2_new = x2_init -grad_x2

    x1_init = x1_new
    x2_init = x2_new

    grad_mag_x1.append(grad_x1)
    grad_mag_x2.append(grad_x2)

    if i == 3:
        grad_x1 = lr*dx1(x1_init, x2_init)
        grad_x2 = lr*dx2(x1_init, x2_init)
        grad_mag_x1.append(grad_x1)
        grad_mag_x2.append(grad_x2)
    
    X1_trajectory.append(x1_init)
    X2_trajectory.append(x2_init)



fig = plt.figure(figsize = (16,8))
ax = fig.add_subplot(1, 2, 1)
ax.contour(X1, X2, Z)
ax.quiver(X1_trajectory, X2_trajectory, grad_mag_x1, grad_mag_x2, scale_units = 'xy', angles = 'xy', scale = 1, color = 'r', alpha = .9)
ax = fig.add_subplot(1, 2, 2, projection='3d')
ax.plot_surface(X1, X2, Z,rstride = 5, cstride = 5, cmap = 'jet', alpha=0.5)
ax.plot3D(X1_trajectory, X2_trajectory, f_2(X1_trajectory, X2_trajectory), marker = '*', color = 'r', alpha = .4, label = 'Gradient descent')
plt.show()

# %% [markdown]
# # Part C

# %%
import numpy as np
import matplotlib.pyplot as plt

def f_3(x1, x2):

    return np.multiply(1+np.power(x1+x2-5, 3),1+np.power(5*x1-2*x2, 4))

def dx1(x1, x2):

    return np.power(x1, 3) + 3*np.multiply(np.power(x1,2),x2) - 15*np.power(x1,2) + 3*np.multiply(x1, np.power(x2,2)) + 75*x1 -30*np.multiply(x1,x2) + np.power(x2, 3) + 75*x2 -15*np.power(x2, 2) -124

def dx2(x1, x2):

    return np.power(x1, 3) + 3*np.multiply(np.power(x1,2),x2) - 15*np.power(x1,2) + 3*np.multiply(x1, np.power(x2,2)) + 75*x1 -30*np.multiply(x1,x2) + np.power(x2, 3) + 75*x2 -15*np.power(x2, 2) -124

x1 = np.arange(9, 20, 0.01)
x2 = np.arange(9, 20, 0.01)

X1, X2 = np.meshgrid(x1, x2)
Z = f_3(X1, X2)

lr = 0.0001

x1_init = 10
x2_init = 10

X1_trajectory = []
X2_trajectory = []

grad_mag_x1 = []
grad_mag_x2 = []

X1_trajectory.append(x1_init)
X2_trajectory.append(x2_init)

for i in range(4):
    
    grad_x1 = lr*dx1(x1_init, x2_init)
    grad_x2 = lr*dx2(x1_init, x2_init)
    x1_new = x1_init -grad_x1
    x2_new = x2_init -grad_x2

    x1_init = x1_new
    x2_init = x2_new

    grad_mag_x1.append(grad_x1)
    grad_mag_x2.append(grad_x2)

    if i == 3:
        grad_x1 = lr*dx1(x1_init, x2_init)
        grad_x2 = lr*dx2(x1_init, x2_init)
        grad_mag_x1.append(grad_x1)
        grad_mag_x2.append(grad_x2)
    
    X1_trajectory.append(x1_init)
    X2_trajectory.append(x2_init)



fig = plt.figure(figsize = (16,8))
ax = fig.add_subplot(1, 2, 1)
ax.contour(X1, X2, Z)
ax.quiver(X1_trajectory, X2_trajectory, grad_mag_x1, grad_mag_x2, scale_units = 'xy', angles = 'xy', scale = 1, color = 'r', alpha = .9)
ax = fig.add_subplot(1, 2, 2, projection='3d')
ax.plot_surface(X1, X2, Z,rstride = 5, cstride = 5, cmap = 'jet', alpha=0.5)
ax.plot3D(X1_trajectory, X2_trajectory, f_3(np.array(X1_trajectory), np.array(X2_trajectory)), marker = '*', color = 'r', alpha = .4, label = 'Gradient descent')
plt.show()

# %% [markdown]
# # Part D

# %%
import numpy as np
import matplotlib.pyplot as plt

def f_4(x1, x2):

    return 3.5*np.power(x1, 2) -9*np.multiply(x1, x2) - 12.5*np.power(x2, 2) + 7*x1 + 8*x2 

def dx1(x1, x2):

    return 7*x1 - 9*x2 + 7

def dx2(x1, x2):

    return -9*x1 - 25*x2 + 8

x1 = np.arange(0, 5, 0.01)
x2 = np.arange(0, 5, 0.01)

X1, X2 = np.meshgrid(x1, x2)
Z = f_4(X1, X2)

lr = 0.01

x1_init = 2
x2_init = 2

X1_trajectory = []
X2_trajectory = []

grad_mag_x1 = []
grad_mag_x2 = []

X1_trajectory.append(x1_init)
X2_trajectory.append(x2_init)

for i in range(4):
    
    grad_x1 = lr*dx1(x1_init, x2_init)
    grad_x2 = lr*dx2(x1_init, x2_init)
    x1_new = x1_init -grad_x1
    x2_new = x2_init -grad_x2

    x1_init = x1_new
    x2_init = x2_new

    grad_mag_x1.append(grad_x1)
    grad_mag_x2.append(grad_x2)

    if i == 3:
        grad_x1 = lr*dx1(x1_init, x2_init)
        grad_x2 = lr*dx2(x1_init, x2_init)
        grad_mag_x1.append(grad_x1)
        grad_mag_x2.append(grad_x2)
    
    X1_trajectory.append(x1_init)
    X2_trajectory.append(x2_init)



fig = plt.figure(figsize = (16,8))
ax = fig.add_subplot(1, 2, 1)
ax.contour(X1, X2, Z)
ax.quiver(X1_trajectory, X2_trajectory, grad_mag_x1, grad_mag_x2, scale_units = 'xy', angles = 'xy', scale = 1, color = 'r', alpha = .9)
ax = fig.add_subplot(1, 2, 2, projection='3d')
ax.plot_surface(X1, X2, Z,rstride = 5, cstride = 5, cmap = 'jet', alpha=0.5)
ax.plot3D(X1_trajectory, X2_trajectory, f_4(np.array(X1_trajectory), np.array(X2_trajectory)), marker = '*', color = 'r', alpha = .4, label = 'Gradient descent')
plt.show()

# %% [markdown]
# # HW1_ex_1_2

# %%
import copy
import numpy as np

class tanh:

    def __init__(self):
        pass

    def forward(self, f_in):
        self.output = np.tanh(f_in)
    
    def backward(self, b_in):
        return np.multiply(1 - np.power(self.output, 2), b_in)
    
class sigmoid:

    def __init__(self):
        pass

    def forward(self, f_in):
        self.output = 1/(1 + np.exp(-f_in))
    
    def backward(self, b_in):
        return np.multiply(b_in, np.multiply(self.output, 1-self.output))


class BCE_loss:

    def __init__(self):
        pass

    def forward(self, y_true, y_predicted):
        y_predicted = np.clip(y_predicted, 0.000001, 0.999999)
        self.output = np.mean(-(y_true*np.log(y_predicted)+(1-y_true)*np.log(1-y_predicted)))

    def backward(self,output, label):

        return -(label/output)+((1-label)/(1-output))
    




inputs = np.random.uniform(-2, 1, (2, 10))
outputs = np.random.randint(0, 2, (1, 10))

W1 = np.random.uniform(-2,2,(3,2))
W2 = np.random.uniform(-2,2,(1,3))
b1 = np.random.uniform(-2,2,(3,1))
b2 = np.random.uniform(-2,2,(1,1))

activation1 = tanh()
activation2 = sigmoid()

lr = 0.1
Loss = BCE_loss()

for epoch in range(10001):

    # SGD optimizer
    for i in range(inputs.shape[1]):

        x = inputs[:,i]
        d = outputs[:,i]

        # forward propagation
        n1 = np.matmul(W1, x) + b1[:,0]
        activation1.forward(n1)
        n2 = np.matmul(W2, activation1.output) + b2[:,0]
        activation2.forward(n2)
        y_predict = copy.copy(activation2.output)
        Loss.forward(d, activation2.output)

        # Backward Propagation

        e = d - activation2.output
        loss_derivative1 = Loss.backward(activation2.output, d)
        s2 = activation2.backward(loss_derivative1)

        loss_derivative2 = np.matmul(W2.T, s2)
        s1 = activation1.backward(loss_derivative2)

        # updating weights and biases

        W1 = W1 - lr*np.matmul(s1.reshape((3,1)),x.reshape((1,2)))
        W2 = W2 - lr*s2*activation1.output.T
        b1 = b1 - lr*s1
        b2 = b2 - lr*s2
    
    
    y_predict[np.where(y_predict>0.5)] = 1
    y_predict[np.where(y_predict<=0.5)] = 0
    accuracy = np.mean(outputs == y_predict)
    if epoch % 100 == 0:
        print(f'Epoch:{epoch}')
        print(f'loss:{Loss.output}')
        print(f'Accuracy: {np.mean(accuracy)}')
        if accuracy == 1:
            break
        # print(Act2.output)
        print('--------------------------')
# Out:
# Epoch:0
# loss:0.31591650633651364
# Accuracy: 0.5
# --------------------------
# Epoch:100
# loss:0.065700681274947
# Accuracy: 0.5
# --------------------------
# Epoch:200
# loss:0.03103395180526139
# Accuracy: 0.5
# --------------------------
# Epoch:300
# loss:0.020413344868395505
# Accuracy: 0.5
# --------------------------
# Epoch:400
# loss:0.01515009931715408
# Accuracy: 0.5
# --------------------------
# Epoch:500
# loss:0.01199988987749732
# Accuracy: 0.5
# --------------------------
# Epoch:600
# loss:0.009905861574548275
# Accuracy: 0.5
# --------------------------
# Epoch:700
# loss:0.00841595249111371
# Accuracy: 0.5
# --------------------------
# Epoch:800
# loss:0.007303663772128892
# Accuracy: 0.5
# --------------------------
# Epoch:900
# loss:0.006442886759962396
# Accuracy: 0.5
# --------------------------
# Epoch:1000
# loss:0.005757849871650728
# Accuracy: 0.5
# --------------------------
# Epoch:1100
# loss:0.005200310344849221
# Accuracy: 0.5
# --------------------------
# Epoch:1200
# loss:0.0047381155180412525
# Accuracy: 0.5
# --------------------------
# Epoch:1300
# loss:0.00434902656457618
# Accuracy: 0.5
# --------------------------
# Epoch:1400
# loss:0.0040171814141470455
# Accuracy: 0.5
# --------------------------
# Epoch:1500
# loss:0.0037309690945500134
# Accuracy: 0.5
# --------------------------
# Epoch:1600
# loss:0.0034816998101605623
# Accuracy: 0.5
# --------------------------
# Epoch:1700
# loss:0.0032627439392295464
# Accuracy: 0.5
# --------------------------
# Epoch:1800
# loss:0.003068957970278927
# Accuracy: 0.5
# --------------------------
# Epoch:1900
# loss:0.002896291823750819
# Accuracy: 0.5
# --------------------------
# Epoch:2000
# loss:0.002741514133388931
# Accuracy: 0.5
# --------------------------
# Epoch:2100
# loss:0.0026020161807317386
# Accuracy: 0.5
# --------------------------
# Epoch:2200
# loss:0.002475669450303641
# Accuracy: 0.5
# --------------------------
# Epoch:2300
# loss:0.0023607204724387203
# Accuracy: 0.5
# --------------------------
# Epoch:2400
# loss:0.0022557120628617605
# Accuracy: 0.5
# --------------------------
# Epoch:2500
# loss:0.002159423553473296
# Accuracy: 0.5
# --------------------------
# Epoch:2600
# loss:0.002070824888626289
# Accuracy: 0.5
# --------------------------
# Epoch:2700
# loss:0.0019890409814109855
# Accuracy: 0.5
# --------------------------
# Epoch:2800
# loss:0.0019133237560519261
# Accuracy: 0.5
# --------------------------
# Epoch:2900
# loss:0.0018430300138752248
# Accuracy: 0.5
# --------------------------
# Epoch:3000
# loss:0.0017776037580925414
# Accuracy: 0.5
# --------------------------
# Epoch:3100
# loss:0.0017165619657714451
# Accuracy: 0.5
# --------------------------
# Epoch:3200
# loss:0.001659483049028895
# Accuracy: 0.5
# --------------------------
# Epoch:3300
# loss:0.0016059974318529465
# Accuracy: 0.5
# --------------------------
# Epoch:3400
# loss:0.0015557798044195884
# Accuracy: 0.5
# --------------------------
# Epoch:3500
# loss:0.00150854271731907
# Accuracy: 0.5
# --------------------------
# Epoch:3600
# loss:0.0014640312534548762
# Accuracy: 0.5
# --------------------------
# Epoch:3700
# loss:0.0014220185723358254
# Accuracy: 0.5
# --------------------------
# Epoch:3800
# loss:0.0013823021649169863
# Accuracy: 0.5
# --------------------------
# Epoch:3900
# loss:0.00134470069050886
# Accuracy: 0.5
# --------------------------
# Epoch:4000
# loss:0.001309051293122459
# Accuracy: 0.5
# --------------------------
# Epoch:4100
# loss:0.0012752073147395996
# Accuracy: 0.5
# --------------------------
# Epoch:4200
# loss:0.001243036338829828
# Accuracy: 0.5
# --------------------------
# Epoch:4300
# loss:0.0012124185098939737
# Accuracy: 0.5
# --------------------------
# Epoch:4400
# loss:0.0011832450847558528
# Accuracy: 0.5
# --------------------------
# Epoch:4500
# loss:0.0011554171792297386
# Accuracy: 0.5
# --------------------------
# Epoch:4600
# loss:0.0011288446801743374
# Accuracy: 0.5
# --------------------------
# Epoch:4700
# loss:0.0011034452980712437
# Accuracy: 0.5
# --------------------------
# Epoch:4800
# loss:0.001079143739450942
# Accuracy: 0.5
# --------------------------
# Epoch:4900
# loss:0.001055870981877183
# Accuracy: 0.5
# --------------------------
# Epoch:5000
# loss:0.0010335636370025077
# Accuracy: 0.5
# --------------------------
# Epoch:5100
# loss:0.0010121633894803685
# Accuracy: 0.5
# --------------------------
# Epoch:5200
# loss:0.0009916165014295605
# Accuracy: 0.5
# --------------------------
# Epoch:5300
# loss:0.0009718733737019851
# Accuracy: 0.5
# --------------------------
# Epoch:5400
# loss:0.0009528881565169393
# Accuracy: 0.5
# --------------------------
# Epoch:5500
# loss:0.0009346184031174138
# Accuracy: 0.5
# --------------------------
# Epoch:5600
# loss:0.0009170247610102373
# Accuracy: 0.5
# --------------------------
# Epoch:5700
# loss:0.0009000706961310776
# Accuracy: 0.5
# --------------------------
# Epoch:5800
# loss:0.0008837222459155096
# Accuracy: 0.5
# --------------------------
# Epoch:5900
# loss:0.0008679477978123585
# Accuracy: 0.5
# --------------------------
# Epoch:6000
# loss:0.0008527178902376337
# Accuracy: 0.5
# --------------------------
# Epoch:6100
# loss:0.0008380050333670817
# Accuracy: 0.5
# --------------------------
# Epoch:6200
# loss:0.0008237835475026444
# Accuracy: 0.5
# --------------------------
# Epoch:6300
# loss:0.0008100294170385194
# Accuracy: 0.5
# --------------------------
# Epoch:6400
# loss:0.000796720158303329
# Accuracy: 0.5
# --------------------------
# Epoch:6500
# loss:0.0007838346997652441
# Accuracy: 0.5
# --------------------------
# Epoch:6600
# loss:0.0007713532732747114
# Accuracy: 0.5
# --------------------------
# Epoch:6700
# loss:0.0007592573151819147
# Accuracy: 0.5
# --------------------------
# Epoch:6800
# loss:0.0007475293762944017
# Accuracy: 0.5
# --------------------------
# Epoch:6900
# loss:0.000736153039775324
# Accuracy: 0.5
# --------------------------
# Epoch:7000
# loss:0.0007251128461723699
# Accuracy: 0.5
# --------------------------
# Epoch:7100
# loss:0.0007143942248727247
# Accuracy: 0.5
# --------------------------
# Epoch:7200
# loss:0.0007039834313458321
# Accuracy: 0.5
# --------------------------
# Epoch:7300
# loss:0.0006938674896175847
# Accuracy: 0.5
# --------------------------
# Epoch:7400
# loss:0.0006840341394731783
# Accuracy: 0.5
# --------------------------
# Epoch:7500
# loss:0.0006744717879412224
# Accuracy: 0.5
# --------------------------
# Epoch:7600
# loss:0.0006651694646627115
# Accuracy: 0.5
# --------------------------
# Epoch:7700
# loss:0.0006561167807853392
# Accuracy: 0.5
# --------------------------
# Epoch:7800
# loss:0.0006473038910641747
# Accuracy: 0.5
# --------------------------
# Epoch:7900
# loss:0.0006387214588800203
# Accuracy: 0.5
# --------------------------
# Epoch:8000
# loss:0.0006303606239206108
# Accuracy: 0.5
# --------------------------
# Epoch:8100
# loss:0.0006222129722856591
# Accuracy: 0.5
# --------------------------
# Epoch:8200
# loss:0.0006142705088136862
# Accuracy: 0.5
# --------------------------
# Epoch:8300
# loss:0.0006065256314338444
# Accuracy: 0.5
# --------------------------
# Epoch:8400
# loss:0.0005989711073785375
# Accuracy: 0.5
# --------------------------
# Epoch:8500
# loss:0.0005916000510963412
# Accuracy: 0.5
# --------------------------
# Epoch:8600
# loss:0.0005844059037295368
# Accuracy: 0.5
# --------------------------
# Epoch:8700
# loss:0.0005773824140252641
# Accuracy: 0.5
# --------------------------
# Epoch:8800
# loss:0.000570523620566212
# Accuracy: 0.5
# --------------------------
# Epoch:8900
# loss:0.0005638238352188952
# Accuracy: 0.5
# --------------------------
# Epoch:9000
# loss:0.0005572776276972552
# Accuracy: 0.5
# --------------------------
# Epoch:9100
# loss:0.0005508798111611113
# Accuracy: 0.5
# --------------------------
# Epoch:9200
# loss:0.0005446254287648971
# Accuracy: 0.5
# --------------------------
# Epoch:9300
# loss:0.0005385097410887916
# Accuracy: 0.5
# --------------------------
# Epoch:9400
# loss:0.0005325282143805925
# Accuracy: 0.5
# --------------------------
# Epoch:9500
# loss:0.0005266765095536842
# Accuracy: 0.5
# --------------------------
# Epoch:9600
# loss:0.0005209504718794693
# Accuracy: 0.5
# --------------------------
# Epoch:9700
# loss:0.0005153461213284081
# Accuracy: 0.5
# --------------------------
# Epoch:9800
# loss:0.0005098596435101617
# Accuracy: 0.5
# --------------------------
# Epoch:9900
# loss:0.000504487381168999
# Accuracy: 0.5
# --------------------------
# Epoch:10000
# loss:0.0004992258261997486
# Accuracy: 0.5
# --------------------------

# %%
np.matmul(W1, x)
# Out:
# array([73.61101501, -5.37784568,  2.35202572])

# %%
b1[:,0]
# Out:
# array([2.73575639, 2.16622739, 4.34152697])

# %% [markdown]
# # HW1_ex_1_3

# %%
P = np.arange(-2, 2, 0.2)
g = 1 + np.sin(np.pi*P/4)

# %%
import matplotlib.pyplot as plt
plt.plot(P,g, 'bo-')
plt.grid()

# %%
import copy
import numpy as np

class Linear:

    def __init__(self):
        pass

    def forward(self, f_in):
        self.output = f_in
    
    def backward(self, b_in):
        return b_in
    
class sigmoid:

    def __init__(self):
        pass

    def forward(self, f_in):
        self.output = 1/(1 + np.exp(-f_in))
    
    def backward(self, b_in):
        return np.multiply(-b_in, np.multiply(self.output, 1-self.output))


class MSE_loss:

    def __init__(self):
        pass

    def forward(self, y_true, y_predicted):
        self.output = np.mean((y_true-y_predicted)**2,axis = 0)

    def backward(self,output, label):

        return -2*(label-output)

P = np.arange(-2, 2, 0.2)
g = 1 + np.sin(np.pi*P/4)    

# W1 = np.random.normal(0,1,(2,1))
# W2 = np.random.normal(0,1,(1,2))
# b1 = np.random.normal(0,1,(1,2,1))
# b2 = np.random.normal(0,1,(1,1))

W1 = np.array([[-0.27],[-0.41]])
W2 = np.array([[0.09, -0.17]])
b1 = np.array([[-0.48],[-0.13]])
b2 = np.array([[0.48]])

activation1 = sigmoid()
activation2 = Linear()

lr = 0.1
Loss = MSE_loss()

for epoch in range(10):

    # SGD optimizer
    for i in range(P.shape[0]):

        x = P[i].reshape((1,1))
        d = g[i]

        # forward propagation
        n1 = np.matmul(W1, x) + b1
        activation1.forward(n1)
        n2 = np.matmul(W2, activation1.output) + b2[:,0]
        activation2.forward(n2)
        y_predict = copy.copy(activation2.output)
        Loss.forward(d, activation2.output)

        # Backward Propagation

        e = d - activation2.output
        loss_derivative1 = Loss.backward(activation2.output, d)
        s2 = activation2.backward(loss_derivative1)


        loss_derivative2 = np.matmul(W2.T, s2)
        s1 = activation1.backward(loss_derivative2)


        # updating weights and biases

        W1 = W1 - lr*np.matmul(s1.reshape((2,1)),x)
        W2 = W2 - lr*s2*activation1.output.T
        b1 = b1 - lr*s1
        b2 = b2 - lr*s2

        # print(W1,"sssssssssssssss")
       # print(b2,"sssssssssssddddddddd")    
    
    y_predict[np.where(y_predict>0.5)] = 1
    y_predict[np.where(y_predict<=0.5)] = 0
    accuracy = np.mean(outputs == y_predict)
   # if epoch % 100 == 0:
    print(f'Epoch:{epoch}')
    print(f'loss:{Loss.output}')
    print(f'Accuracy: {np.mean(accuracy)}')
    #if accuracy == 1:
    #    break
    # print(Act2.output)
    print('--------------------------')
# Out:
# Epoch:0
# loss:[0.1392537]
# Accuracy: 0.0
# --------------------------
# Epoch:1
# loss:[0.12478926]
# Accuracy: 0.0
# --------------------------
# Epoch:2
# loss:[0.10547527]
# Accuracy: 0.0
# --------------------------
# Epoch:3
# loss:[0.09154463]
# Accuracy: 0.0
# --------------------------
# Epoch:4
# loss:[0.0853092]
# Accuracy: 0.0
# --------------------------
# Epoch:5
# loss:[0.08182242]
# Accuracy: 0.0
# --------------------------
# Epoch:6
# loss:[0.07051195]
# Accuracy: 0.0
# --------------------------
# Epoch:7
# loss:[0.05251822]
# Accuracy: 0.0
# --------------------------
# Epoch:8
# loss:[0.03977178]
# Accuracy: 0.0
# --------------------------
# Epoch:9
# loss:[0.03562167]
# Accuracy: 0.0
# --------------------------

# %%
activation1 = sigmoid()
activation2 = Linear()

x = P[15].reshape((1,1))
d = g[15]

W1 = np.array([[-0.27],[-0.41]])
W2 = np.array([[0.09, -0.17]])
b1 = np.array([[-0.48],[-0.13]])
b2 = np.array([[0.48]])

# forward propagation
n1 = np.matmul(W1, x) + b1
activation1.forward(n1)
n2 = np.matmul(W2, activation1.output) + b2[:,0]
activation2.forward(n2)
y_predict = copy.copy(activation2.output)
Loss.forward(d, activation2.output)

# Backward Propagation

e = d - activation2.output
loss_derivative1 = Loss.backward(activation2.output, d)
s2 = activation2.backward(loss_derivative1)


loss_derivative2 = np.matmul(W2.T, s2)
s1 = activation1.backward(loss_derivative2)


# updating weights and biases

W1 = W1 - lr*np.matmul(s1.reshape((2,1)),x)
W2 = W2 - lr*s2*activation1.output.T
b1 = b1 - lr*s1
b2 = b2 - lr*s2

print(W1,"sdddddddddddddddddddddgggggggggggdd")
print(b1,"eqweqeqe")
print(W2,"eqweqeqggggggggge")
print(b2,"eqweqeqffffffffffff|e")
# Out:
# [[-0.27494509]
#  [-0.4000278 ]] sdddddddddddddddddddddgggggggggggdd
# [[-0.48494509]
#  [-0.1200278 ]] eqweqeqe
# [[ 0.17089989 -0.077156  ]] eqweqeqggggggggge
# [[0.73216495]] eqweqeqffffffffffff|e

# %%
x
# Out:
# array([[1.]])

# %% [markdown]
# # HW1_ex_1_3

# %%
import copy
import numpy as np

class Linear:

    def __init__(self):
        pass

    def forward(self, f_in):
        self.output = f_in
    
    def backward(self, b_in):
        return b_in
    
class ReLU:

    def __init__(self):
        pass

    def forward(self, f_in):
        self.output = np.maximum(0,f_in)
        self.input = f_in
    
    def backward(self, b_in):
        self.b_output = b_in
        self.b_output[self.input<=0] = 0
        return self.b_output


class MSE_loss:

    def __init__(self):
        pass

    def forward(self, y_true, y_predicted):
        self.output = np.mean((y_true-y_predicted)**2,axis = 0)

    def backward(self,output, label):

        return -2*(label-output)

P = np.array([[-1, 0,  2, -1],
              [-4, 2, -3, 1]])

outputs = np.array([[2.2, 5.7, -2.9, 1.8]])

W1 = np.random.normal(0,1,(3,2))
W2 = np.random.normal(0,1,(1,3))
#W_bypass = np.random.normal(0,1,(1,1))
b1 = np.random.normal(0,1,(3,1))
b2 = np.random.normal(0,1,(1,1))

activation1 = ReLU()
activation2 = Linear()

lr = 0.1
Loss = MSE_loss()

for epoch in range(10):

    # SGD optimizer
    for i in range(P.shape[0]):

        x = P[:,i]
        d = outputs[:,i]

    #     # forward propagation
    #     n1 = np.matmul(W1, x) + b1[:,0]
    #    # skip = W_bypass*x[0]
    #     activation1.forward(n1)
    #     n2 = np.matmul(W2, activation1.output) + b2
    #     activation2.forward(n2)
    #     y_predict = copy.copy(activation2.output)
    #     Loss.forward(d, activation2.output)

    #     print(activation2.output,"sssssssssssssss")
        
    #     # Backward Propagation

    #     e = d - activation2.output
    #     loss_derivative1 = Loss.backward(activation2.output, d)
    #     s2 = activation2.backward(loss_derivative1)
        

    #     loss_derivative2 = np.matmul(W2.T, s2)
    #     s1 = activation1.backward(loss_derivative2)
    #     print(s1.shape,"sddddddddddddddddddddddd")

    #     # updating weights and biases

    #     W1 = W1 - lr*np.matmul(s1,x.reshape(1,2))
    #     W2 = W2 - lr*s2*activation1.output.T
    #     # W_bypass = W_bypass - lr*s2*x[0]
    #     b1 = b1 - lr*s1
    #     b2 = b2 - lr*s2

        n1 = np.matmul(W1, x) + b1[:,0]
        activation1.forward(n1)
        n2 = np.matmul(W2, activation1.output) + b2[:,0]
        activation2.forward(n2)
        y_predict = copy.copy(activation2.output)
        Loss.forward(d, activation2.output)

        
        # Backward Propagation

        e = d - activation2.output
        loss_derivative1 = Loss.backward(activation2.output, d)
        s2 = activation2.backward(loss_derivative1)


        loss_derivative2 = np.matmul(W2.T, s2)
        s1 = activation1.backward(loss_derivative2)
        print(Loss,"ssssssssssssssssssss")

        # updating weights and biases

        W1 = W1 - lr*np.matmul(s1.reshape((3,1)),x.reshape(1,2))
        W2 = W2 - lr*s2*activation1.output.T
        b1 = b1 - lr*s1
        b2 = b2 - lr*s2

        # print(W1,"sssssssssssssss")
       # print(b2,"sssssssssssddddddddd")    
    
#     y_predict[np.where(y_predict>0.5)] = 1
#     y_predict[np.where(y_predict<=0.5)] = 0
#     accuracy = np.mean(outputs == y_predict)
#    # if epoch % 100 == 0:
#     print(f'Epoch:{epoch}')
#     print(f'loss:{Loss.output}')
#     print(f'Accuracy: {np.mean(accuracy)}')
#     #if accuracy == 1:
#     #    break
#     # print(Act2.output)
#     print('--------------------------')
# Out:
# [-1.85489661] ssssssssssssssssssss
# [-12.06302004] ssssssssssssssssssss
# [6.30461203] ssssssssssssssssssss
# [-4.26388557] ssssssssssssssssssss
# [-25.13906123] ssssssssssssssssssss
# [478.49052448] ssssssssssssssssssss
# [-6445653.65625038] ssssssssssssssssssss
# [1.87452205e+19] ssssssssssssssssssss
# [-4.61073012e+56] ssssssssssssssssssss
# [6.86131166e+168] ssssssssssssssssssss
# [-inf] ssssssssssssssssssss
# [nan] ssssssssssssssssssss
# [nan] ssssssssssssssssssss
# [nan] ssssssssssssssssssss
# [nan] ssssssssssssssssssss
# [nan] ssssssssssssssssssss
# [nan] ssssssssssssssssssss
# [nan] ssssssssssssssssssss
# [nan] ssssssssssssssssssss
# [nan] ssssssssssssssssssss
# C:\Users\TUF\AppData\Local\Temp\ipykernel_21488\1136409761.py:36: RuntimeWarning: overflow encountered in square
#   self.output = np.mean((y_true-y_predicted)**2,axis = 0)
# C:\Users\TUF\AppData\Local\Temp\ipykernel_21488\1136409761.py:99: RuntimeWarning: overflow encountered in matmul
#   n2 = np.matmul(W2, activation1.output) + b2[:,0]
# C:\Users\TUF\AppData\Local\Temp\ipykernel_21488\1136409761.py:119: RuntimeWarning: invalid value encountered in multiply
#   W2 = W2 - lr*s2*activation1.output.T
# C:\Users\TUF\AppData\Local\Temp\ipykernel_21488\1136409761.py:97: RuntimeWarning: invalid value encountered in matmul
#   n1 = np.matmul(W1, x) + b1[:,0]
